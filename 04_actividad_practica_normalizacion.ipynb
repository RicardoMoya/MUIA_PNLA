# %% [markdown]
# Nombre alumno/a: Nombre Apellido_1 Apellido_2
#
# # Explicación de los pasos realizados en la normalización del corpus
#
# * Descripción
#
# Pasos:
# 1. Paso 1
# 2. Paso 2
# 3. ...

# %%
# Código

textos = [
    "María López asistió a una jornada sobre IA en Madrid y envió sus dudas a soporte@microsoft.com después de la sesión.",
    "Ramón Ruiz participó en un taller de Microsoft Azure en Barcelona y solicitó acceso a los materiales escribiendo a formacion@microsoft.com.",
    "Lucía Torres presentó un proyecto sobre modelos generativos en Valencia y compartió sus resultados con el equipo mediante investigacion@openai.com.",
    "Lola Fernández viajó a Nueva York para asistir a una conferencia de OpenAI y confirmó su inscripción en eventos@openai.com.",
    "Pedro García preparó una propuesta sobre análisis de sentimientos en Sevilla y pidió revisión técnica a soporte@openai.com antes de entregarla.",
    "El profesor Ricardo Moya explicó tokenización y lematización en U-tad durante la clase de Procesamiento del Lenguaje Natural.",
    "Ricardo Moya organizó una sesión práctica en San Lorenzo del Escorial sobre spaCy y resolvió las incidencias recibidas en soporte@u-tad.com.",
    "Marta Sánchez desarrolló un pequeño clasificador de noticias en Python y Visual Studio Code y documentó el experimento para sus compañeros de U-tad.",
    "Microsoft Research presentó nuevas herramientas de productividad en Castilla y León y varios estudiantes analizaron el anuncio como ejemplo de texto corporativo.",
    "OpenAI publicó una guía sobre seguridad en modelos generativos y el grupo debatió sus implicaciones durante el seminario de NLP en U-tad."
]

# %% [markdown]
# # Conclusión sobre las decisiones tomadas durante el proceso de normalización
#
# * Conclusiones
